# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv('happiness_score.csv')
df
# Out:
#          Country                           Region  Happiness Rank  \
# 0    Switzerland                   Western Europe               1
# 1        Iceland                   Western Europe               2
# 2        Denmark                   Western Europe               3
# 3         Norway                   Western Europe               4
# 4         Canada                    North America               5
# ..           ...                              ...             ...
# 153       Rwanda               Sub-Saharan Africa             154
# 154        Benin               Sub-Saharan Africa             155
# 155        Syria  Middle East and Northern Africa             156
# 156      Burundi               Sub-Saharan Africa             157
# 157         Togo               Sub-Saharan Africa             158
#
#      Happiness Score  Standard Error  Economy (GDP per Capita)   Family  \
# 0              7.587         0.03411                   1.39651  1.34951
# ...

# %%
df.shape
# Out:
# (158, 12)

# %%
print(df.columns,'\n')
print('total variables---->',len(df.columns))
# Out:
# Index(['Country', 'Region', 'Happiness Rank', 'Happiness Score',
#        'Standard Error', 'Economy (GDP per Capita)', 'Family',
#        'Health (Life Expectancy)', 'Freedom', 'Trust (Government Corruption)',
#        'Generosity', 'Dystopia Residual'],
#       dtype='object')
#
# total variables----> 12

# %%
df.dtypes
# Out:
# Country                           object
# Region                            object
# Happiness Rank                     int64
# Happiness Score                  float64
# Standard Error                   float64
# Economy (GDP per Capita)         float64
# Family                           float64
# Health (Life Expectancy)         float64
# Freedom                          float64
# Trust (Government Corruption)    float64
# Generosity                       float64
# Dystopia Residual                float64
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 158 entries, 0 to 157
# Data columns (total 12 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Country                        158 non-null    object
#  1   Region                         158 non-null    object
#  2   Happiness Rank                 158 non-null    int64
#  3   Happiness Score                158 non-null    float64
#  4   Standard Error                 158 non-null    float64
#  5   Economy (GDP per Capita)       158 non-null    float64
#  6   Family                         158 non-null    float64
#  7   Health (Life Expectancy)       158 non-null    float64
#  8   Freedom                        158 non-null    float64
#  9   Trust (Government Corruption)  158 non-null    float64
#  10  Generosity                     158 non-null    float64
#  11  Dystopia Residual              158 non-null    float64
# ...

# %% [markdown]
# interpretation:
#
#        1) there are total 12 variables pesent in the dataset.
#        2)the datasets contains 2 objests, 1 integer and 9 float values.
#        3)no null values present in the dataset.

# %%
#checking for missing values

sns.heatmap(df.isnull())

# %%
df.isnull().sum()
# Out:
# Country                          0
# Region                           0
# Happiness Rank                   0
# Happiness Score                  0
# Standard Error                   0
# Economy (GDP per Capita)         0
# Family                           0
# Health (Life Expectancy)         0
# Freedom                          0
# Trust (Government Corruption)    0
# Generosity                       0
# Dystopia Residual                0
# dtype: int64

# %% [markdown]
# interpretation:
#
#     there is no null values are present in the dataset.

# %%
#summary statistics

df.describe()
# Out:
#        Happiness Rank  Happiness Score  Standard Error  \
# count      158.000000       158.000000      158.000000
# mean        79.493671         5.375734        0.047885
# std         45.754363         1.145010        0.017146
# min          1.000000         2.839000        0.018480
# 25%         40.250000         4.526000        0.037268
# 50%         79.500000         5.232500        0.043940
# 75%        118.750000         6.243750        0.052300
# max        158.000000         7.587000        0.136930
#
#        Economy (GDP per Capita)      Family  Health (Life Expectancy)  \
# count                158.000000  158.000000                158.000000
# mean                   0.846137    0.991046                  0.630259
# std                    0.403121    0.272369                  0.247078
# min                    0.000000    0.000000                  0.000000
# 25%                    0.545808    0.856823                  0.439185
# ...

# %% [markdown]
# interpretations:
#
#     1)almost every variables mean value is less than 1
#     2)variation from mean is also minimum for all variables
#     3)6 variables minimum value is zero
#     4)for all variables mean and median value is aproximately same

# %%
#correlation between the variables

df.corr()
# Out:
#                                Happiness Rank  Happiness Score  \
# Happiness Rank                       1.000000        -0.992105
# Happiness Score                     -0.992105         1.000000
# Standard Error                       0.158516        -0.177254
# Economy (GDP per Capita)            -0.785267         0.780966
# Family                              -0.733644         0.740605
# Health (Life Expectancy)            -0.735613         0.724200
# Freedom                             -0.556886         0.568211
# Trust (Government Corruption)       -0.372315         0.395199
# Generosity                          -0.160142         0.180319
# Dystopia Residual                   -0.521999         0.530474
#
#                                Standard Error  Economy (GDP per Capita)  \
# Happiness Rank                       0.158516                 -0.785267
# Happiness Score                     -0.177254                  0.780966
# ...

# %%
plt.figure(figsize=(10,10))
sns.heatmap(df.corr(),annot=True)

# %% [markdown]
# interpretation
#
#     1)most of the variables are positively correlated
#     2)happiness rank is negatively correlated to all variable except std. error
#     3)happiness score is positively correlated to all variables except std. error
#     4)standar error is negaively correlated to all variables except G.residuals
#     5)Happiness Rank higely neagtively correlated with Happiness Score.

# %%
#Exploratory data analysis univariate
#data cleaning for region variable

print(df['Region'].unique(),"\n")
print('total category---->',len(df['Region'].unique()))
# Out:
# ['Western Europe' 'North America' 'Australia and New Zealand'
#  'Middle East and Northern Africa' 'Latin America and Caribbean'
#  'Southeastern Asia' 'Central and Eastern Europe' 'Eastern Asia'
#  'Sub-Saharan Africa' 'Southern Asia']
#
# total category----> 10

# %%
print(df['Region'].value_counts())
xb=df['Region'].value_counts().index
# Out:
# Sub-Saharan Africa                 40
# Central and Eastern Europe         29
# Latin America and Caribbean        22
# Western Europe                     21
# Middle East and Northern Africa    20
# Southeastern Asia                   9
# Southern Asia                       7
# Eastern Asia                        6
# Australia and New Zealand           2
# North America                       2
# Name: Region, dtype: int64

# %%
plt.figure(figsize=(12,5))
plt.bar(list(xb),df['Region'].value_counts())
plt.xticks(rotation = 20)
plt.xlabel('Region')
plt.ylabel('number of counts')
plt.title('regional barplot')
plt.show()

# %% [markdown]
# interpretation
#
#      1)sub-saharan african coutries has maximum number of countries in happiness index
#      2)north american, asian coutries are less in happiness index

# %%
#we are dropping the Region column because is has categorical objective variales and  variable country  it won't affect the model

df.drop(labels=['Country','Region'],axis=1,inplace=True)
df.head()
# Out:
#    Happiness Rank  Happiness Score  Standard Error  Economy (GDP per Capita)  \
# 0               1            7.587         0.03411                   1.39651
# 1               2            7.561         0.04884                   1.30232
# 2               3            7.527         0.03328                   1.32548
# 3               4            7.522         0.03880                   1.45900
# 4               5            7.427         0.03553                   1.32629
#
#     Family  Health (Life Expectancy)  Freedom  Trust (Government Corruption)  \
# 0  1.34951                   0.94143  0.66557                        0.41978
# 1  1.40223                   0.94784  0.62877                        0.14145
# 2  1.36058                   0.87464  0.64938                        0.48357
# 3  1.33095                   0.88521  0.66973                        0.36503
# 4  1.32261                   0.90563  0.63297                        0.32957
#
#    Generosity  Dystopia Residual
# ...

# %%
#exploratory Data Analysis-univariate- variable (happiness score)
#we are plotting violine plot to check the bulk data in the variable

sns.violinplot(df['Happiness Score'])
print('minimum happiness core---->',df['Happiness Score'].min(),'\n','maximum happiness score---->',df['Happiness Score'].max())
# Out:
# minimum happiness core----> 2.839
#  maximum happiness score----> 7.587000000000001

# %% [markdown]
# interpretation
#
#     1)as we can see the maximum number of coutry has happiness score between 4-6
#     2)minimum happiness score is 2.839 and maximum happiness score is 7.587

# %%
#Exploratory Data Analysis-bivariate
#cheking relation between two variables

plt.scatter(df['Economy (GDP per Capita)'],df['Happiness Score'])
plt.ylabel('happiness score')
plt.xlabel('Economy (GDP per Capita)')
plt.title('scatterplot between  happiness score and Economy (GDP per Capita)')
# Out:
# Text(0.5, 1.0, 'scatterplot between  happiness score and Economy (GDP per Capita)')

# %% [markdown]
# interpretation:
#
#     1)as coutries economy increases happiness score is also increases
#     2)itis positively ralated

# %%
#cheking relation between two variables

plt.scatter(df['Economy (GDP per Capita)'],df['Happiness Score'])
plt.ylabel('happiness score')
plt.xlabel('Economy (GDP per Capita)')
plt.title('scatterplot between  happiness score and Economy (GDP per Capita)')
# Out:
# Text(0.5, 1.0, 'scatterplot between  happiness score and Economy (GDP per Capita)')

# %%
plt.scatter(df['Health (Life Expectancy)'],df['Happiness Score'])
plt.ylabel('happiness score')
plt.xlabel('Health (Life Expectancy)')
plt.title('scatterplot between  happiness score and Health (Life Expectancy)')
# Out:
# Text(0.5, 1.0, 'scatterplot between  happiness score and Health (Life Expectancy)')

# %% [markdown]
# interpretation:
#
#     1)as health of people is good happiness score is high
#     2)it is positively ralated

# %%
plt.scatter(df['Trust (Government Corruption)'],df['Happiness Score'])
plt.ylabel('happiness score')
plt.xlabel('Trust (Government Corruption)')
plt.title('scatterplot between  happiness score and Trust (Government Corruption)')
# Out:
# Text(0.5, 1.0, 'scatterplot between  happiness score and Trust (Government Corruption)')

# %% [markdown]
# interpretation:as we see data is approximately scatters therefore corruption and happiness score is not that much related

# %%
#checking for otliers

collist=df.columns.values
plt.figure(figsize=(15,55))
for i in range(1,len(collist)):
    plt.subplot(8,10,i+1)
    sns.boxplot(df[collist[i]],color='blue',orient='v')
    plt.tight_layout

# %% [markdown]
# interpretation:
#
#     1)as we can see that otliers are present in some variables not all variables
#     2)but oue distance between third quartile and maximum value is not more in all variales
#     3)our data contains only 158 rows if we remove otliers we will lost more data so we can take as it is for further calculation

# %%
#cheking for skewness

collist=df.columns.values
plt.figure(figsize=(15,25))
for i in range(1,len(collist)):
    plt.subplot(5,5,i+1)
    sns.distplot(df[collist[i]],color='blue')

# %% [markdown]
# interpretation:
#
#     1)as we can see there is skewness present in some variable but not in all
#     2)as we see in description table our difference between mean value and median value is not that much.

# %%
#dropping happiness rank beacuse it depends on happiness score

df.drop(labels=['Happiness Rank'],axis=1,inplace=True)

# %%
x=df.iloc[:,1:]
x.head()
# Out:
#    Standard Error  Economy (GDP per Capita)   Family  \
# 0         0.03411                   1.39651  1.34951
# 1         0.04884                   1.30232  1.40223
# 2         0.03328                   1.32548  1.36058
# 3         0.03880                   1.45900  1.33095
# 4         0.03553                   1.32629  1.32261
#
#    Health (Life Expectancy)  Freedom  Trust (Government Corruption)  \
# 0                   0.94143  0.66557                        0.41978
# 1                   0.94784  0.62877                        0.14145
# 2                   0.87464  0.64938                        0.48357
# 3                   0.88521  0.66973                        0.36503
# 4                   0.90563  0.63297                        0.32957
#
#    Generosity  Dystopia Residual
# 0     0.29678            2.51738
# 1     0.43630            2.70201
# 2     0.34139            2.49204
# 3     0.34699            2.46531
# 4     0.45811            2.45176

# %%
x.shape
# Out:
# (158, 8)

# %%
y=df.iloc[:,0:1]
y.head()
# Out:
#    Happiness Score
# 0            7.587
# 1            7.561
# 2            7.527
# 3            7.522
# 4            7.427

# %%
y.shape
# Out:
# (158, 1)

# %%
#model building

from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, mean_absolute_error
from sklearn.metrics import r2_score

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=.25,random_state=45)
print('xtrain shape--->',x_train.shape)
print('ytrain shape--->',y_train.shape)
print('xtest shape--->',x_test.shape)
print('ytest shape--->',y_test.shape)
# Out:
# xtrain shape---> (118, 8)
# ytrain shape---> (118, 1)
# xtest shape---> (40, 8)
# ytest shape---> (40, 1)

# %%
#we use linear regression model because it has all continuous variables

lrm=LinearRegression()
lrm.fit(x_train,y_train)
print(lrm.coef_)
print(lrm.intercept_)
# Out:
# [[-4.70623161e-04  9.99979386e-01  1.00014114e+00  9.99952272e-01
#    9.99506800e-01  1.00001165e+00  1.00009894e+00  1.00004597e+00]]
# [-1.6463026e-05]

# %%
score=lrm.score(x_train,y_train)
score
# Out:
# 0.9999999422095333

# %%
pred=lrm.predict(x_test)
print('predicted result:',pred)
print('actual result:',y_test)
# Out:
# predicted result: [[4.87426565]
#  [7.58686595]
#  [3.67767858]
#  [4.2184619 ]
#  [5.19376529]
#  [7.5221224 ]
#  [4.07670162]
#  [4.5714669 ]
#  [5.10160405]
#  [6.4111179 ]
#  [4.55062897]
#  [3.81911876]
#  [7.27771293]
#  [4.29659117]
#  [5.47370166]
#  [4.36909084]
#  [5.42853925]
#  [3.65589245]
#  [3.95568715]
#  [5.75855993]
#  [3.65500739]
#  [6.29467206]
#  [4.25196448]
#  [4.60978198]
#  [5.99510473]
#  [5.19234613]
#  [4.33198836]
#  [5.70881119]
#  [3.99482891]
#  [7.42687261]
#  [6.32892145]
#  [6.57501836]
#  [6.1676053 ]
#  [5.07323244]
#  [4.884448  ]
#  [3.98872324]
#  [4.68549347]
#  [6.7500928 ]
#  [5.36023493]
#  [7.18727742]]
# actual result:      Happiness Score
# 99             4.874
# 0              7.587
# 147            3.678
# 133            4.218
# 80             5.194
# 3              7.522
# 135            4.077
# 115            4.571
# 87             5.102
# 34             6.411
# 117            4.550
# 144            3.819
# 10             7.278
# ...

# %%
print('errors:')
print('mean squared error:',mean_squared_error(y_test,pred))
print('mean absolute error:',mean_absolute_error(y_test,pred))
print('root mean squared error:',np.sqrt(mean_squared_error(y_test,pred)))
print('r2 score:',r2_score(y_test,pred))
print('score:',score*100,'%')
# Out:
# errors:
# mean squared error: 8.970758125446459e-08
# mean absolute error: 0.0002544109497166325
# root mean squared error: 0.00029951223890596623
# r2 score: 0.9999999350154078
# score: 99.99999422095333 %

# %% [markdown]
# interpretation:
#
#     as we see that we used linear model and our score is 99.99%
#     for further prediction we use linear model.

# %%
#exporting model

import joblib
from joblib import dump

# %%
joblib.dump(lrm,'happiness_score.pkl')
# Out:
# ['happiness_score.pkl']
